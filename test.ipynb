# %%
import util
import fbp
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
img = Image.open('images/Brady-square.jpg')
plt.imshow(img, cmap='gray')

# %%
img, startX, startY = util.pad_img(img)
angles = np.linspace(0,180,180,endpoint=False)
sinogram = util.projection(img, angles)
plt.imshow(sinogram, cmap='gray')

# %%
reconstructed = fbp.fbp(sinogram, angles)

# %%
plt.imshow(reconstructed, cmap='gray')

# %% [markdown]
# Our library works. Filtering and Backprojection separated.
